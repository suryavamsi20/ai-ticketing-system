# %%
import joblib

joblib.dump(model, "../models/ticket_type_model.pkl")
joblib.dump(tfidf, "../models/tfidf_vectorizer.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import joblib
# ----> 3 joblib.dump(model, "../models/ticket_type_model.pkl")
#       4 joblib.dump(tfidf, "../models/tfidf_vectorizer.pkl")
#
# NameError: name 'model' is not defined
